# %%
import pandas as pd
data = pd.read_csv('../processed_data/train_att.csv')
x = pd.read_csv('../processed_data/train_machine.csv')

# %%
data
# Out:
#                                              audio_path  domain  \
# 0     data/ToyCar/train/section_00_source_train_norm...  source
# 1     data/ToyCar/train/section_00_source_train_norm...  source
# 2     data/ToyCar/train/section_00_source_train_norm...  source
# 3     data/ToyCar/train/section_00_source_train_norm...  source
# 4     data/ToyCar/train/section_00_source_train_norm...  source
# ...                                                 ...     ...
# 8995  data/bearing/train/section_00_target_train_nor...  target
# 8996  data/bearing/train/section_00_target_train_nor...  target
# 8997  data/bearing/train/section_00_target_train_nor...  target
# 8998  data/bearing/train/section_00_target_train_nor...  target
# 8999  data/bearing/train/section_00_target_train_nor...  target
#
#                                    label
# 0     ToyCar_source_car_B1_spd_31V_mic_1
# 1     ToyCar_source_car_B1_spd_31V_mic_1
# 2     ToyCar_source_car_B1_spd_31V_mic_1
# ...

# %%
import pandas as pd
train_data = pd.read_csv('../processed_data/train_machine.csv')
audio_path = train_data[train_data['domain']=='source']['audio_path'].reset_index(drop=True)

# %%
train_data
# Out:
#                                               audio_path  domain  \
# 0      data/gearbox/train/section_00_source_train_nor...  source
# 1      data/gearbox/train/section_00_source_train_nor...  source
# 2      data/gearbox/train/section_00_source_train_nor...  source
# 3      data/gearbox/train/section_00_source_train_nor...  source
# 4      data/gearbox/train/section_00_source_train_nor...  source
# ...                                                  ...     ...
# 15995  data/AirCompressor/train/section_00_target_tra...  target
# 15996  data/AirCompressor/train/section_00_target_tra...  target
# 15997  data/AirCompressor/train/section_00_target_tra...  target
# 15998  data/AirCompressor/train/section_00_target_tra...  target
# 15999  data/AirCompressor/train/section_00_target_tra...  target
#
#        machine_label                             label
# 0            gearbox        gearbox_source_noAttribute
# 1            gearbox        gearbox_source_noAttribute
# ...
